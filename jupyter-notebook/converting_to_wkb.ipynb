# %%
import geopandas as gpd
gdf = gpd.read_file("USA-ADM1.geojson")
gdf["wkb"] = gdf.geometry.apply(lambda g: g.wkb)

# %%
gdf["wkb"]
# Out:
# 0     b'\x01\x06\x00\x00\x00\x08\x00\x00\x00\x01\x03...
# 1     b'\x01\x06\x00\x00\x00\r\x00\x00\x00\x01\x03\x...
# 2     b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xf0\x03...
# 3     b'\x01\x06\x00\x00\x00\x0b\x00\x00\x00\x01\x03...
# 4     b'\x01\x03\x00\x00\x00\x01\x00\x00\x00B\x06\x0...
# 5     b'\x01\x06\x00\x00\x00.\x00\x00\x00\x01\x03\x0...
# 6     b'\x01\x06\x00\x00\x00i\x00\x00\x00\x01\x03\x0...
# 7     b'\x01\x06\x00\x00\x00!\x00\x00\x00\x01\x03\x0...
# 8     b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xc2\x06...
# 9     b'\x01\x06\x00\x00\x00t\x00\x00\x00\x01\x03\x0...
# 10    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00<\x02\x0...
# 11    b'\x01\x06\x00\x00\x00:\x00\x00\x00\x01\x03\x0...
# 12    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00q\x00\x0...
# 13    b'\x01\x06\x00\x00\x00\x0e\x00\x00\x00\x01\x03...
# 14    b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\xe3\x01...
# 15    b'\x01\x06\x00\x00\x00\x1f\x00\x00\x00\x01\x03...
# 16    b'\x01\x06\x00\x00\x00\r\x00\x00\x00\x01\x03\x...
# ...
